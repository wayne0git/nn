# %% [markdown]
# # Tensorflow logistics regression example

# %% [markdown]
# ##### Ref : https://github.com/c1mone/Tensorflow-101/blob/master/notebooks/Logistic_Regression.ipynb

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\Users\pc\Anaconda3\envs\tf110\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Test Data preparation
x_data = np.random.rand(100).astype(np.float32)
y_data = x_data * 0.1 + 0.3

# %%
# Create Model
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

# %%
# Define loss function and optimizer
loss = tf.reduce_mean(tf.square(y - y_data))
optimizer = tf.train.GradientDescentOptimizer(0.2)
train = optimizer.minimize(loss)

# %%
# Initialize variable
init = tf.global_variables_initializer()

# %%
# Launch and run the graph
with tf.Session() as sess:
    # Launch the graph
    sess.run(init)
    
    # Training
    for step in range(100):
        sess.run(train)
        if step % 20 == 0:
            plt.plot(x_data, y_data, 'ro', label='Original data')
            plt.plot(x_data, sess.run(W) * x_data + sess.run(b), label='Fitted line')
            plt.legend()
            plt.show()
